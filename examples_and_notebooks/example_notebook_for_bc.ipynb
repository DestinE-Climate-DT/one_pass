# %% [markdown]
# Example notebook on how to run the OPA for output for bias-correction.
#
# ## First testing on some netCDF lat lon data saved on disk

# %%
import numpy as np 
import os 
import sys 
import glob 
import xarray as xr
import pickle 

path = "/home/b/b382291/git/one_pass"
sys.path.append(path)
os.chdir(path)

from one_pass.convert_time import convert_time
from one_pass.check_request import check_request
from one_pass import util
from one_pass.opa import Opa

! hostname
# Out:
# l20592.lvt.dkrz.de

# %% [markdown]
# loading 10 month test data from disk located in the tests folder on the one_pass repo

# %%
file_path = "/home/b/b382291/git/one_pass/tests/uas_10_months.nc"
data = xr.open_dataset(file_path, engine='netcdf4')
data
# Out:
# <xarray.Dataset>
# Dimensions:   (time: 6960, lon: 100, lat: 100)
# Coordinates:
#   * time      (time) datetime64[ns] 2020-05-01T00:15:00 ... 2021-09-30T23:15:00
#   * lon       (lon) float64 -174.9 -174.9 -174.8 -174.8 ... -170.1 -170.0 -170.0
#   * lat       (lat) float64 -85.0 -84.95 -84.9 -84.85 ... -80.15 -80.1 -80.05
#     height_2  float64 ...
# Data variables:
#     uas       (time, lat, lon) float32 ...

# %% [markdown]
# Configuration file or dictionary to be passed to the OPA. Rather than have a seperate key value pair where "bias_correction" : True, it made a lot more sense for the OPA logic to have it simply passed as a statistic. You **MUST** set the stat_freq and output_freq = daily. This ensures you feed daily means into the digests.

# %%
pass_dic = {"stat" : "bias_correction",
"percentile_list" : None,
"threshold_exceed" : None,
"stat_freq": "daily",
"output_freq": "daily",
"time_step": 60,
"variable": "uas",
"save": True,
"checkpoint": True,
"checkpoint_filepath": "/scratch/b/b382291/data/",
"out_filepath": "/scratch/b/b382291/data"}

# %% [markdown]
# Here we're just running a loop of 24 hours (data has hourly frequency) to simulate the streaming, as passing steps set by the parameter step. If step is = 1, we're passing one hour of data at each point. The loading bars that are output are more for diagnostics and are showing the loop of initalising the digests over the whole grid, updating the digests and spending them through a picklable class.

# %%
step = 6
start =  0 
stop =  24*90  

for i in range(start, stop, step): 

    ds = data.isel(time=slice(i,i+step)) # extract moving window 'simulating streaming'
    # can pass either a dictionary as above or data from the config file 
    #daily_mean = Opa("config.yml")
    opa_stat = Opa(pass_dic)
    dm = opa_stat.compute(ds) # computing algorithm with new data
# Out:
# initalising digests
# 100%|██████████| 10000/10000 [00:00<00:00, 568087.55it/s]
# 100%|██████████| 10000/10000 [00:00<00:00, 242518.21it/s]
#   0%|          | 0/10000 [00:00<?, ?it/s]
# 100%|██████████| 10000/10000 [00:00<00:00, 852535.47it/s]
# finished saving tdigest files in 0.1496 s
# 100%|██████████| 10000/10000 [00:00<00:00, 189733.42it/s]
# 100%|██████████| 10000/10000 [00:00<00:00, 821108.44it/s]
# finished saving tdigest files in 0.1729 s
# 100%|██████████| 10000/10000 [00:00<00:00, 157513.02it/s]
# 100%|██████████| 10000/10000 [00:00<00:00, 801832.19it/s]
# finished saving tdigest files in 0.1808 s
# 100%|██████████| 10000/10000 [00:00<00:00, 145801.10it/s]
# 100%|██████████| 10000/10000 [00:00<00:00, 811418.62it/s]
# finished saving tdigest files in 0.1754 s
# 100%|██████████| 10000/10000 [00:00<00:00, 144713.51it/s]
# 100%|██████████| 10000/10000 [00:00<00:00, 824903.43it/s]
# finished saving tdigest files in 0.1735 s
# 100%|██████████| 10000/10000 [00:00<00:00, 184083.42it/s]
# 100%|██████████| 10000/10000 [00:00<00:00, 854237.07it/s]
# finished saving tdigest files in 0.1717 s
# 100%|██████████| 10000/10000 [00:00<00:00, 156395.34it/s]
# 100%|██████████| 10000/10000 [00:00<00:00, 837754.96it/s]
# finished saving tdigest files in 0.1743 s
# 100%|██████████| 10000/10000 [00:00<00:00, 167325.73it/s]
# 100%|██████████| 10000/10000 [00:00<00:00,

# Coordinates:
#   * time      (time) datetime64[ns] 2020-05-01T00:15:00 ... 2021-09-30T23:15:00
#   * lon       (lon) float64 -174.9 -174.9 -174.8 -174.8 ... -170.1 -170.0 -170.0
#   * lat       (lat) float64 -85.0 -84.95 -84.9 -84.85 ... -80.15 -80.1 -80.05
#     height_2  float64 ...
# Data variables:
#     uas       (time, lat, lon) float32 ...
# Attributes:
#     OPA:      daily bias_correction calculated using one-pass algorithm

# %% [markdown]
# Updated 14/7/23: The output of the bias-correction will now 3 files.
# 1. will be the raw data at native temporal resolution over 1 day
# 2. daily mean of the same day (need to know which variables require means and which require summations)
# 3. an updated pkl file. There will be one file per month, which contains tDigest objects, each updated with the daily means. The weight of the centroids (at least for the first year) should correspond to the number of days in the month.
#
# Known problems:
# If a day is missing in a month it currently won't get picked up, because mainly working with the daily resolution
# If the tdigest file is too large (above 2GB) this is not serializable and needs to be saved with.zarr For small files like this example, no problem

# %%
# raw data file 

file_path = "/scratch/b/b382291/data/2020_05_03_uas_raw_data_for_bc.nc"
data = xr.open_dataset(file_path, engine='netcdf4')
data
# Out:
# <xarray.Dataset>
# Dimensions:   (time: 24, lon: 100, lat: 100)
# Coordinates:
#   * time      (time) datetime64[ns] 2020-05-03T00:15:00 ... 2020-05-03T23:15:00
#   * lon       (lon) float64 -174.9 -174.9 -174.8 -174.8 ... -170.1 -170.0 -170.0
#   * lat       (lat) float64 -85.0 -84.95 -84.9 -84.85 ... -80.15 -80.1 -80.05
#     height_2  float64 ...
# Data variables:
#     uas       (time, lat, lon) float32 ...
# Attributes:
#     OPA:      raw data at native temporal resolution saved by one-pass algorithm

# %%
# daily mean file 

file_path = "/scratch/b/b382291/data/2020_05_03_uas_daily_mean.nc"
data = xr.open_dataset(file_path, engine='netcdf4')
data
# Out:
# <xarray.Dataset>
# Dimensions:   (time: 1, lat: 100, lon: 100)
# Coordinates:
#   * time      (time) datetime64[ns] 2020-05-03T00:15:00
#   * lon       (lon) float64 -174.9 -174.9 -174.8 -174.8 ... -170.1 -170.0 -170.0
#   * lat       (lat) float64 -85.0 -84.95 -84.9 -84.85 ... -80.15 -80.1 -80.05
#     height_2  float64 ...
# Data variables:
#     uas       (time, lat, lon) float64 ...
# Attributes:
#     OPA:      daily mean calculated using one-pass algorithm

# %% [markdown]
# The next output file is a pickle file. I have chosen to pass this information as a pickle instead of a netCDF for a few reasons:
#
# 1. We can pass the actual TDigest objects, rather than needing to extract the centriods and means and manipulate the data causing extra overhead
# 2. Much faster to save
#
# To deserialise this data do the following:

# %%
 # monthly tdigest file fed with daily means across that month 
 
file_path = "/scratch/b/b382291/data/month_05_uas_bias_correction.pkl"

f = open(file_path, 'rb')
digest_data = pickle.load(f)

digest_data
# Out:
# <xarray.Dataset>
# Dimensions:   (time: 1, lat: 100, lon: 100)
# Coordinates:
#   * time      (time) datetime64[ns] 2020-05-31T00:15:00
#   * lon       (lon) float64 -174.9 -174.9 -174.8 -174.8 ... -170.1 -170.0 -170.0
#   * lat       (lat) float64 -85.0 -84.95 -84.9 -84.85 ... -80.15 -80.1 -80.05
#     height_2  float64 ...
# Data variables:
#     uas       (time, lat, lon) object TDigest(mean=-0.781, weight=31, centroi...
# Attributes:
#     OPA:      daily means accumulated monthly for bias_correction calculated ...

# %% [markdown]
# The data is still on the given grid that was initally passed. To inspect each digest you can:

# %%
digest_data_uas = digest_data.uas
digest_data_uas
# Out:
# <xarray.DataArray 'uas' (time: 1, lat: 100, lon: 100)>
# array([[[TDigest(mean=-0.781, weight=31, centroids=11, merged, compression=15),
#          TDigest(mean=-0.804, weight=31, centroids=12, merged, compression=15),
#          TDigest(mean=-0.819, weight=31, centroids=12, merged, compression=15),
#          ...,
#          TDigest(mean=-0.969, weight=31, centroids=11, merged, compression=15),
#          TDigest(mean=-0.92, weight=31, centroids=12, merged, compression=15),
#          TDigest(mean=-0.472, weight=31, centroids=11, merged, compression=15)],
#         [TDigest(mean=-1.43, weight=31, centroids=11, merged, compression=15),
#          TDigest(mean=-2.06, weight=31, centroids=10, merged, compression=15),
#          TDigest(mean=-2.13, weight=31, centroids=10, merged, compression=15),
#          ...,
#          TDigest(mean=-2.92, weight=31, centroids=11, merged, compression=15),
#          TDigest(mean=-2.73, weight=31, centroids=11, merged, compression=15),
#          TDigest(mean=-2.58, weight=31, centroids=11, merged, compression=15)],
#         [TDigest(mean=-2.25, weight=31, centroids=10, merged, compression=15),
#          TDigest(mean=-2.41, weight=31, centroids=10, merged, compression=15),
#          TDigest(mean=-3.19, weight=31, centroids=11, merged, compression=15),
#          ...,
#          TDigest(mean=-4.79, weight=31, centroids=11, merged, compression=15),
#          TDigest(mean=-4.68, weight=31, centroids=11, merged, compression=15),
# ...
#          TDigest(mean=0.148, weight=31, centroids=11, merged, compression=15),
#          ...,
#          TDigest(mean=-0.458, weight=31, centroids=11, merged, compression=15),
#          TDigest(mean=-0.498, weight=31, centroids=11, merged, compression=15),
#          TDigest(mean=-0.498, weight=31, centroids=11, merged, compression=15)],
#         [TDigest(mean=0.188, weight=31, centroids=11, merged, compression=15),
#          TDigest(mean=0.182, weight=31, centroids=11, merged, compression=15),
#          TDigest(mean=0.181, weight=31, centroids=11, merged, compression=15),
#          ...,
#          TDigest(mean=-0.439, weight=31, centroids=11, merged, compression=15),
#          TDigest(mean=-0.441, weight=31, centroids=11, merged, compression=15),
#          TDigest(mean=-0.442, weight=31, centroids=11, merged, compression=15)],
#         [TDigest(mean=0.22, weight=31, centroids=11, merged, compression=15),
#          TDigest(mean=0.213, weight=31, centroids=11, merged, compression=15),
#          TDigest(mean=0.212, weight=31, centroids=11, merged, compression=15),
#          ...,
#          TDigest(mean=-0.411, weight=31, centroids=11, merged, compression=15),
#          TDigest(mean=-0.412, weight=31, centroids=11, merged, compression=15),
#          TDigest(mean=-0.414, weight=31, centroids=11, merged, compression=15)]]],
#       dtype=object)
# Coordinates:
#   * time      (time) datetime64[ns] 2020-05-31T00:15:00
#   * lon       (lon) float64 -174.9 -174.9 -174.8 -174.8 ... -170.1 -170.0 -170.0
#   * lat       (lat) float64 -85.0 -84.95 -84.9 -84.85 ... -80.15 -80.1 -80.05
#     height_2  float64 ...
# Attributes:
#     OPA:      daily means accumulated monthly for bias_correction calculated ...

# %% [markdown]
# If you want to extract an actual digest you can do the following. You can call any pytdigest attribute you want on this object

# %%
one_digest = digest_data_uas.values[0, 1,1]
one_digest.inverse_cdf([0.6])
# Out:
# array([-0.84796929])

# %% [markdown]
# ## Another example but using the AQUA frame work - for this you need to be on Levante

# %%
path = "/home/b/b382291/git/AQUA/"
sys.path.append(path)
os.chdir(path)

from aqua import Reader

# %% [markdown]
# This is using the AQUA readers fake streamer, which is a really good way of simulating data streaming. This is will keep looping. AQUA repo can be found here: https://github.com/oloapinivad/AQUA

# %% [markdown]
# This example below will be a lot slower as, for the selected FESOM data, the grid has 7 million data points.

# %%
# this is our user requst 

pass_dic = {"stat" : "bias_correction",
"percentile_list" : None,
"threshold_exceed" : None,
"stat_freq": "daily",
"output_freq": "daily",
"time_step": 60,
"variable": "sst",
"save": True,
"checkpoint": True,
"checkpoint_filepath": "/scratch/b/b382291/data/",
"out_filepath": "/scratch/b/b382291/data"}


reader = Reader(model = 'FESOM', exp = 'tco2559-ng5-cycle3', source = '2D_1h_native')
reader.reset_stream()
data_gen = reader.retrieve(streaming_generator=True, stream_step=12, stream_unit = 'hours')# , stream_startdate='2022-12-01')
#data_gen = reader.retrieve(streaming=True, stream_step=3, stream_unit = 'days')

for data in data_gen:
    
    print(f"start_date: {data.time[0].values} stop_date: {data.time[-1].values}")
    data = data['sst']
    opa_stat = Opa(pass_dic)
    dm = opa_stat.compute(data)
# Out:
# start_date: 2020-01-20T00:56:00.000000000 stop_date: 2020-01-20T11:56:00.000000000
# WARNING: timings of input data span over new statistic
# 1.3793 s to load dask
# start_date: 2020-01-20T12:56:00.000000000 stop_date: 2020-01-20T23:56:00.000000000
# initalising digests
# 100%|██████████| 7402886/7402886 [00:22<00:00, 327105.67it/s]
# 100%|██████████| 7402886/7402886 [00:30<00:00, 244041.35it/s]
# 100%|██████████| 7402886/7402886 [00:12<00:00, 571994.09it/s]
# finished saving tdigest files in 113.9578 s
# start_date: 2020-01-21T00:56:00.000000000 stop_date: 2020-01-21T11:56:00.000000000
# WARNING: timings of input data span over new statistic
# 3.1049 s to load dask
# start_date: 2020-01-21T12:56:00.000000000 stop_date: 2020-01-21T23:56:00.000000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 26
#      24 data = data['sst']
#      25 opa_stat = Opa(pass_dic)
# ---> 26 dm = opa_stat.compute(data)
#
# File ~/git/one_pass/one_pass/opa.py:1354, in Opa.compute(self, ds)
#    1351     self._get_percentile(ds) # this will give self.tdigest but it's full of percentiles
#    1353 if(self.stat == "bias_correction"):
# -> 1354     dm_raw, dm_mean = self._create_and_save_outputs_for_bc(ds) # loads, updates and makes picklabe tdigests, saves daily raw and daily mean
#    1356 dm, final_time_file_str = self._data_output(ds) # output as a dataset
#    1358 if(self.time_append == 1): #output_freq_min == self.stat_freq_min
#
# File ~/git/one_pass/one_pass/opa.py:1226, in Opa._create_and_save_outputs_for_bc(self, ds)
#    1224 ds_size = ds.tail(time = 1)
#    1225 # now want to pass daily mean into bias_corr
# -> 1226 self._load_or_init_digests(ds_size) # load or initalise the monthly digest file
#    1227 self._update_tdigest(self.mean_cum, 1) # update digests with daily mean /
#    1228 # we know the weight = 1 as it's the mean over that day,
#
# File ~/git/one_pass/one_pass/opa.py:924, in Opa._load_or_init_digests(self, ds_size)
#     921 self.checkpoint_file_bc = os.path.join(self.out_filepath, f'month_{final_time_file_str}_{self.variable}_{self.stat}.pkl')
#     923 if (os.path.exists(self.checkpoint_file_bc)): # this is loading the t-digest class
# --> 924     temp_self = self._load_pickle_for_bc(self.checkpoint_file_bc)
#     925     # extracting the underlying list out of the xarray dataSet
#     926     self.bias_correction_cum = temp_self[self.variable].values
#
# File ~/git/one_pass/one_pass/opa.py:112, in Opa._load_pickle_for_bc(self, file_path)
#     109 def _load_pickle_for_bc(self, file_path):
#     111     f = open(file_path, 'rb')
# --> 112     temp_self = pickle.load(f)
#     113     f.close()
#     115     return temp_self
#
# File ~/git/one_pass/one_pass/opa.py:47, in PicklableTDigest.__setstate__(self, state)
#      41     state = {
#      42         'centroids': self.tdigest.get_centroids(),
#      43         'compression': self.tdigest.compression
#      44     }
#      45     return state
# ---> 47 def __setstate__(self, state):
#      48     """Then here we use the data we serialized to deserialize it.
#      49
#      50     We use that data to create a new instance of TDigest. It has
#    (...)
#      53     Here ``of_centroids`` is used to demonstrate how it works.
#      54     """
#      55     self.tdigest = TDigest.of_centroids(
#      56         centroids=state['centroids'],
#      57         compression=state['compression']
#      58     )
#
# KeyboardInterrupt:
